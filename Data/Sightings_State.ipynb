# %%
#Imports
import os
import pandas as pd
import numpy as np

# %%
#Read CSV
ufo_data = pd.read_csv('../UFO_data.csv')

# %%
#Remove American Territories - US States Only
ufo_data = ufo_data.drop(ufo_data[ufo_data['State'] == "American Samoa"].index)

# %%
ufo_data
# Out:
#                      Date            City State Country     Shape  \
# 0     2022-07-31 21:59:00  West Lafayette    OH     USA     Light
# 1     2022-07-31 21:45:00      Burr Ridge    IL     USA     Other
# 2     2022-07-31 21:15:00          Conway    SC     USA    Circle
# 3     2022-07-31 21:11:00          Keyser    WV     USA     Light
# 4     2022-07-31 20:43:00        gressham    OR     USA   Unknown
# ...                   ...             ...   ...     ...       ...
# 2055  2022-12-01 18:10:00       Blakeslee    OH     USA    Sphere
# 2056  2022-12-01 18:00:00       Snowflake    AZ     USA  Triangle
# 2057  2022-12-01 14:10:00         El paso    TX     USA      Oval
# 2058  2022-12-01 06:20:00     CHARLESTOWN    IN     USA     Light
# 2059  2022-12-01 03:59:00       Mansfield    TX     USA  Changing
#
#                 Duration                                            Summary  \
# 0              4 minutes            Bright circle light moving through sky.
# ...

# %%
states = ufo_data.groupby(['State']).count()
states
# Out:
#        Date  City  Country  Shape  Duration  Summary  Posted  Images  \
# State
# AK        3     3        3      2         3        3       3       3
# AL       28    28       28     28        28       28      28      10
# AR       18    18       18     18        17       18      18       5
# AZ       64    64       64     62        62       64      64      23
# CA      203   203      203    202       193      203     203      41
# CO       58    58       58     58        51       58      58      13
# CT       35    35       35     32        32       35      35      12
# DC        3     3        3      3         3        3       3       2
# DE       11    11       11     11        11       11      11       3
# FL      152   152      152    151       149      152     152      42
# GA       35    35       35     35        34       35      35       9
# HI        5     5        5      5         5        5       5       1
# ...

# %%
#Summary of UFO Sightings by State
print("Count of UFO Sightings by State:")
states = ufo_data.groupby(['State']).size().to_frame(name = 'Sightings').reset_index()
states
# Out:
# Count of UFO Sightings by State:
#    State  Sightings
# 0     AK          3
# 1     AL         28
# 2     AR         18
# 3     AZ         64
# 4     CA        203
# 5     CO         58
# 6     CT         35
# 7     DC          3
# 8     DE         11
# 9     FL        152
# 10    GA         35
# 11    HI          5
# 12    IA         14
# 13    ID         24
# 14    IL         58
# 15    IN         38
# 16    KS         12
# 17    KY         27
# 18    LA         21
# 19    MA         53
# 20    MD         31
# 21    ME         25
# 22    MI         50
# 23    MN         33
# 24    MO         42
# 25    MS         12
# 26    MT         18
# 27    NC         67
# 28    ND          2
# 29    NE          8
# 30    NH         24
# 31    NJ         54
# 32    NM         27
# 33    NV         26
# 34    NY        103
# 35    OH         75
# 36    OK         26
# 37    ON          1
# 38    OR         51
# 39    PA        113
# 40    RI         12
# 41    SC         30
# ...

# %%
ufo_state = ufo_data.groupby('State').count()['City']

# %%
# write to csv file
states.to_csv('sightings_state.csv')
