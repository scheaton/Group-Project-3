# %%
import pandas as pd

# %%
Dec2022 = pd.read_csv('Dec22_Data.csv')
Nov2022 = pd.read_csv('Nov22_Data.csv')
Oct2022 = pd.read_csv('Oct22_Data.csv')
Sep2022 = pd.read_csv('Sep22_Data.csv')
Aug2022 = pd.read_csv('Aug22_Data.csv')
Jul2022 = pd.read_csv('Jul22_Data.csv')


summary1 = Jul2022.append(Aug2022)
summary2 = Aug2022.append(Sep2022)
summary3 = Sep2022.append(Oct2022)
summary4 = Oct2022.append(Nov2022)
summary = summary4.append(Dec2022)

# %%
summary.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)
summary.drop(["a"], axis=1, inplace=True)

# %%
summary
# Out:
#                Date                  City State Country     Shape  \
# 0    10/31/22 23:30  Rancho mission viejo    CA     USA   Unknown
# 1    10/31/22 22:45         New Braunfels    TX     USA   Chevron
# 2    10/31/22 19:11               Concord    CA     USA     Light
# 3    10/31/22 15:32       New Port Richey    FL     USA      Disk
# 4    10/31/22 06:30          Granite lake    SA  Canada      Disk
# ..              ...                   ...   ...     ...       ...
# 153   12/1/22 18:00             Snowflake    AZ     USA  Triangle
# 154   12/1/22 15:33                   NaN   NaN     USA     Cross
# 155   12/1/22 14:10               El paso    TX     USA      Oval
# 156   12/1/22 06:20           CHARLESTOWN    IN     USA     Light
# 157   12/1/22 03:59             Mansfield    TX     USA  Changing
#
#                     Duration  \
# 0              10-15 seconds
# 1                  7 seconds
# 2    So far it’s been 40mins
# 3                  2 minutes
# 4                    2 hours
# ..                       ...
# 153                2 minutes
# 154                      NaN
# 155              Ten minutes
# 156           2 to 3 minutes
# 157               60 seconds
#
#                                                Summary    Posted Images
# 0    It was more like a long light of orange as if ...  12/22/22    NaN
# 1    Dim gray object flew silently while spreading ...  12/22/22    NaN
# 2    A circle of light flying in a circle motion cr...  12/22/22    NaN
# 3            Bright white Flashing lights on the craft  12/22/22    NaN
# 4    One craft was seen in front of my friends cabi...  12/22/22    NaN
# ..                                                 ...       ...    ...
# 153  I grew up on a 40 acre parcel of land with thr...  12/22/22    NaN
# 154  I observed some type of phenomenon that I was ...  12/22/22    Yes
# 155  It appeared out of nowhere & slowly moved acro...  12/22/22    NaN
# 156  Bright object was seen arriving and silently h...  12/22/22    Yes
# 157  Looked like a drone but moved way too fast the...  12/22/22    NaN
#
# [958 rows x 9 columns]
